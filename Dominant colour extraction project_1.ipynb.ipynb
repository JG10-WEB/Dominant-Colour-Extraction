# %% [markdown]
# Reference Research Paper : Dominant Color Extraction with K-Means for Camera Characteristics in Cultural Heritage Documentation

# %%
import numpy as np #importing the libraries
from matplotlib import pyplot as plt
# %matplotlib inline
import cv2
from sklearn.cluster import KMeans

# %%
image = cv2.imread("/content/modern-scenery-painting-500x500.jpeg") #Reading the image 
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #Converting from BGR to RGB
plt.imshow(image)

# %%
print(image.shape) #Rehsaping to 2D from 3D
image = image.reshape((image.shape[0] * image.shape[1], 3))
print(image.shape)
# Out:
# (500, 500, 3)
# (250000, 3)

# %% [markdown]
# Clusters = 8

# %%
km = KMeans(n_clusters=8) # Defining the number of Clusters
km.fit(pixels)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
colors = np.asarray(km.cluster_centers_, dtype='uint8') # Obtainnig the different cluster centres
print(colors)
# Out:
# [[206 212 234]
#  [142 104  99]
#  [ 33  29  26]
#  [254 254 254]
#  [170 186  66]
#  [164  29  27]
#  [187 176 161]
#  [ 91 131  34]]

# %%
percentage = np.asarray(np.unique(km.labels_, return_counts = True)[1], dtype='float32')  #Printing the percentages of the labels
percentage = percentage/pixels.shape[0]
percentage
# Out:
# array([0.10611111, 0.05666667, 0.23986112, 0.31138888, 0.06520833,
#        0.03145833, 0.09090278, 0.09840278], dtype=float32)

# %%
for px in range(pixels.shape[0]):
    for ix in range(colors.shape[0]):
        pixels[px] =colors[km.labels_[px]]

# %%
img = pixels.reshape(out_r, -1, 3)
print(img.shape)
# Out:
# (120, 120, 3)

# %%
plt.imshow(img)

# %% [markdown]
# Clusters = 5

# %%
km = KMeans(n_clusters=5) # Defining the number of Clusters
km.fit(pixels)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
colors = np.asarray(km.cluster_centers_, dtype='uint8') # Obtainnig the different cluster centres
print(colors)
# Out:
# [[169 186  65]
#  [186 176 161]
#  [ 33  28  26]
#  [241 243 248]
#  [118 105  52]]

# %%
percentage = np.asarray(np.unique(km.labels_, return_counts = True)[1], dtype='float32')  #Printing the percentages of the labels
percentage = percentage/pixels.shape[0]
percentage
# Out:
# array([0.06520833, 0.09090278, 0.23986112, 0.4175    , 0.18652777],
#       dtype=float32)

# %%
for px in range(pixels.shape[0]):
    for ix in range(colors.shape[0]):
        pixels[px] =colors[km.labels_[px]]

# %%
img = pixels.reshape(out_r, -1, 3)
print(img.shape)
# Out:
# (120, 120, 3)

# %%
plt.imshow(img)

# %% [markdown]
# Clusters = 3

# %%
km = KMeans(n_clusters=3) # Defining the number of Clusters
km.fit(pixels)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
colors = np.asarray(km.cluster_centers_, dtype='uint8') # Obtainnig the different cluster centres
print(colors)
# Out:
# [[145 139  83]
#  [241 243 247]
#  [ 33  28  25]]

# %%
percentage = np.asarray(np.unique(km.labels_, return_counts = True)[1], dtype='float32')  #Printing the percentages of the labels
percentage = percentage/pixels.shape[0]
percentage
# Out:
# array([0.34263888, 0.4175    , 0.23986112], dtype=float32)

# %%
for px in range(pixels.shape[0]):
    for ix in range(colors.shape[0]):
        pixels[px] =colors[km.labels_[px]]

# %%
img = pixels.reshape(out_r, -1, 3)
print(img.shape)
# Out:
# (120, 120, 3)

# %%
plt.imshow(img)

# %% [markdown]
# Highest percentage in 8 clusters is 31.138%, 5 clusters is 41.75% and in 3 clusters is also 41.75%.
